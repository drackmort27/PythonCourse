# %%
texto = "Una linea con texto \nOtra linea con texto"

# %%
fichero = open('fichero.txt','w') #nombre y el modo en el que se abre

# %%
fichero.write(texto)
# Out:
# 41

# %%
fichero.close()

# %%
del(fichero)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 del(fichero)
#
# NameError: name 'fichero' is not defined

# %%
fichero  = open('fichero.txt','r')

# %%
texto = fichero.read()

# %%
fichero.close()
print(texto)
# Out:
# Una linea con texto
# Otra linea con texto

# %%
del(fichero)

# %%
fichero = open('fichero.txt','r')

# %%
lineas = fichero.readlines()

# %%
fichero.close()

# %%
del(fichero)

# %%
lineas
# Out:
# ['Una linea con texto \n', 'Otra linea con texto']
