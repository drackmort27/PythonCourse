# %%
"Hola mundo".upper()
# Out:
# 'HOLA MUNDO'

# %%
"hOLA MUNDO".lower()
# Out:
# 'hola mundo'

# %%
"hola mundo".capitalize()
# Out:
# 'Hola mundo'

# %%
"Hola mundo".title()
# Out:
# 'Hola Mundo'

# %%
"Hola mundo".count('mundo')
# Out:
# 1

# %%
"Hola mundo".find('mundo')
# Out:
# 5

# %%
"Hola mundo".rfind('mundo')
# Out:
# 5

# %%
c = "100"

# %%
c.isdigit()
# Out:
# True

# %%
c2 = "ABC19939PO"

# %%
c2.isalnum()
# Out:
# True

# %%
c2.isalpha()
# Out:
# False

# %%
"Hola mundo".islower()
# Out:
# False

# %%
"Hola mundo".isupper()
# Out:
# False

# %%
"Hola mundo".istitle()
# Out:
# False

# %%
"Hola mundo".isspace()
# Out:
# False

# %%
"Hola mundo".startswith('h')
# Out:
# False

# %%
"Hola mundo".endswith('o')
# Out:
# True

# %%
"Hola mundo".split()
# Out:
# ['Hola', 'mundo']
