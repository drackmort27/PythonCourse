# %%
#La clase es como un molde para crear objetos
class Galleta:
    pass

# %%
#Proceso de crear un objeto a partir de su clase se denomina instanciacion, un objeto es una instancia de clase
#Instancia algo que existe en la memoria mientras exista el programa
una_galleta = Galleta() 
otra_galleta = Galleta()

# %%
type(una_galleta)
# Out:
# __main__.Galleta
