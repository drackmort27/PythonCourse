# %%
def resta(a=None,b=None):
    if a == None or b == None:
        print("Error, debes enviar dos numeros a la funcion")
        return 
    else:
        return a-b
resta()
# Out:
# Error, debes enviar dos numeros a la funcion

# %%
resta(a=2,b=1) #Se pasa los valores de los argumentos sin importar posicion
# Out:
# 1
