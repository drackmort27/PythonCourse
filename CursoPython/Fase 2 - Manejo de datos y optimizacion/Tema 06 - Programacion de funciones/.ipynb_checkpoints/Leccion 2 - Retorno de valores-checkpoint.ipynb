# %%
def test():
    return "Una cadena retornada"
    #Todo lo que se coloque abajo de este no se ejecutara(similar al break)
test()
# Out:
# 'Una cadena retornada'

# %%
print(test())
# Out:
# Una cadena retornada

# %%
c = test()
print(c)
# Out:
# Una cadena retornada

# %%
def test():
    return "Una cadena",20,[1,2,3]
test()
# Out:
# ('Una cadena', 20, [1, 2, 3])

# %%
c,n,l = test()
print(c,n,l)
# Out:
# Una cadena 20 [1, 2, 3]
