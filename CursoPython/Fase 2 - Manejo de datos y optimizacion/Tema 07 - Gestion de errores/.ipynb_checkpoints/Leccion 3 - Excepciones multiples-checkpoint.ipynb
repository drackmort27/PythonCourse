# %%
try:
    n = input("Introduce un numero: ")
    5/n
except Exception as e: #Guardamos el identificador del error en la variable e
    print(type(e).__name__)
# Out:
# Introduce un numero:  s
# TypeError
