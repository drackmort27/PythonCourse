# %%
valor = input()
# Out:
#  100

# %%
valor
# Out:
# '100'

# %%
type(valor)
# Out:
# str

# %%
2 + int(valor)
# Out:
# 102

# %%
nombre = input("Introduce nombre")
apellido = input("Introduce apellido")
edad = int(input("Introduce edad"))
numero_magico = float(input("Introduce numero magico"))
cadena_final = print(f"{nombre} {apellido} : Tu número de la suerte es el {edad*numero_magico}")
# Out:
# Introduce nombre luciano
# Introduce apellido somare
# Introduce edad 27
# Introduce numero magico 1.5
# luciano somare : Tu número de la suerte es el 40.5
