# %%
# Completa el ejercicio
numero = int(input("Ingrese un numero: "))

while numero%5 != 0:
    numero = int(input("Incorrecto, ingrese otro numero: "))
print("Correcto, es multiplo de 5")
# Out:
# Ingrese un numero:  2
# Incorrecto, ingrese otro numero:  2
# Incorrecto, ingrese otro numero:  1
# Incorrecto, ingrese otro numero:  2
# Incorrecto, ingrese otro numero:  1
# Incorrecto, ingrese otro numero:  2
# Incorrecto, ingrese otro numero:  3
# Incorrecto, ingrese otro numero:  2
# Incorrecto, ingrese otro numero:  5
# Correcto, es multiplo de 5
